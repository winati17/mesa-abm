# %% [markdown]
# <a href="https://colab.research.google.com/github/SFIComplexityExplorer/Mesa-ABM-Tutorial/blob/main/Session_9_Traders_Move_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Winati Mutmainnah (D121221014)

# %% [markdown]
# # Import Dependencies

# %%
import mesa
import numpy as np
import math
import matplotlib.pyplot as plt

# %% [markdown]
# # Resource Classes

# %%
class Sugar(mesa.Agent):
  """
  Sugar:
  - contains an amount of sugar
  - grows 1 amount of sugar at each turn
  """

  def __init__(self, unique_id, model, pos, max_sugar):
    super().__init__(unique_id, model)
    self.pos = pos
    self.amount = max_sugar
    self.max_sugar = max_sugar


  def step(self):
    '''
    Sugar growth function, adds one unit of sugar each step until
    max amount
    '''
    self.amount = min([self.max_sugar, self.amount+1])

# %%
class Spice(mesa.Agent):
  """
  Spice:
  - contains an amount of spice
  - grows 1 amount of spice at each turn
  """

  def __init__(self, unique_id, model, pos, max_spice):
    super().__init__(unique_id, model)
    self.pos = pos
    self.amount = max_spice
    self.max_spice = max_spice

  def step(self):
    '''
    Spice growth function, adds one unit of spice each step until
    max amout
    '''
    self.amount = min([self.max_spice, self.amount+1])

# %% [markdown]
# # Trader Agent

# %%
class Trader(mesa.Agent):
  """
  Trader:
  - has a metabolism of sugar and spice
  - harvest and trade sugar and spice to survive
  """

  def __init__(self, unique_id, model, pos, moore=False, sugar=0,
               spice=0, metabolism_sugar=0, metabolism_spice=0,
               vision=0):
    super().__init__(unique_id, model)
    self.pos = pos
    self.moore = moore
    self.sugar = sugar
    self.spice = spice
    self.metabolism_sugar = metabolism_sugar
    self.metabolism_spice = metabolism_spice
    self.vision = vision

    def move(self):
        print(f"I am agent {self.unique_id} and am about to move")

# %% [markdown]
# # Model Class

# %%
class SugarscapeG1mt(mesa.Model):
    """
    Manager class to run Sugarscape with Traders
    """

    def __init__(self, width=50, height=50, initial_population=200,
                 endowment_min=25, endowment_max=50, metabolism_min=1,
                 metabolism_max=5, vision_min=1, vision_max=5):

        # Initialize the base Model class
        super().__init__()

        # Initialize width and height of sugarscape
        self.width = width
        self.height = height

        # Initialize population attributes
        self.initial_population = initial_population
        self.endowment_min = endowment_min
        self.endowment_max = endowment_max
        self.metabolism_min = metabolism_min
        self.metabolism_max = metabolism_max
        self.vision_min = vision_min
        self.vision_max = vision_max

        # Initiate activation schedule
        self.schedule = mesa.time.RandomActivationByType(self)
        # Initiate mesa grid class
        self.grid = mesa.space.MultiGrid(self.width, self.height, torus=False)

        # Read in landscape file from supplementary material
        sugar_distribution = np.genfromtxt("sugar-map.txt")
        spice_distribution = np.flip(sugar_distribution, 1)

        agent_id = 0
        for _, (x, y) in self.grid.coord_iter():
            max_sugar = sugar_distribution[x, y]
            if max_sugar > 0:
                sugar = Sugar(agent_id, self, (x, y), max_sugar)
                self.schedule.add(sugar)
                self.grid.place_agent(sugar, (x, y))
                agent_id += 1

            max_spice = spice_distribution[x, y]
            if max_spice > 0:
                spice = Spice(agent_id, self, (x, y), max_spice)
                self.schedule.add(spice)
                self.grid.place_agent(spice, (x, y))
                agent_id += 1

        for i in range(self.initial_population):
            # Get agent position
            x = self.random.randrange(self.width)
            y = self.random.randrange(self.height)
            # Give agents initial endowment
            sugar = int(self.random.uniform(self.endowment_min, self.endowment_max + 1))
            spice = int(self.random.uniform(self.endowment_min, self.endowment_max + 1))
            # Give agents initial metabolism
            metabolism_sugar = int(self.random.uniform(self.metabolism_min, self.metabolism_max + 1))
            metabolism_spice = int(self.random.uniform(self.metabolism_min, self.metabolism_max + 1))
            # Give agents vision
            vision = int(self.random.uniform(self.vision_min, self.vision_max + 1))
            # Create Trader object
            trader = Trader(agent_id,
                            self,
                            (x, y),
                            moore=False,
                            sugar=sugar,
                            spice=spice,
                            metabolism_sugar=metabolism_sugar,
                            metabolism_spice=metabolism_spice,
                            vision=vision)
            # Place agent
            self.grid.place_agent(trader, (x, y))
            self.schedule.add(trader)
            agent_id += 1

    def step(self):
        '''
        Unique step function that does staged activation of sugar and spice
        and then randomly activates traders
        '''
        # Step Sugar agents
        for sugar in self.schedule.agents_by_type[Sugar].values():
            sugar.step()

        # Step Spice agents
        for spice in self.schedule.agents_by_type[Spice].values():
            spice.step()

        # Step Trader agents
        trader_shuffle = list(self.schedule.agents_by_type[Trader].values())
        self.random.shuffle(trader_shuffle)

        for agent in trader_shuffle:
            agent.move()

        self.schedule.steps += 1  # Important for data collector to track number of steps

    def run_model(self, step_count=1000):
        for i in range(step_count):
            self.step()

# %% [markdown]
# # Run Sugarscape

# %%
model = SugarscapeG1mt()
model.run_model(step_count=1)
# Out:
# I am agent 4210 and am about to move
# I am agent 4285 and am about to move
# I am agent 4226 and am about to move
# I am agent 4289 and am about to move
# I am agent 4267 and am about to move
# I am agent 4244 and am about to move
# I am agent 4328 and am about to move
# I am agent 4259 and am about to move
# I am agent 4266 and am about to move
# I am agent 4151 and am about to move
# I am agent 4190 and am about to move
# I am agent 4318 and am about to move
# I am agent 4160 and am about to move
# I am agent 4138 and am about to move
# I am agent 4175 and am about to move
# I am agent 4144 and am about to move
# I am agent 4245 and am about to move
# I am agent 4284 and am about to move
# I am agent 4273 and am about to move
# I am agent 4188 and am about to move
# I am agent 4164 and am about to move
# I am agent 4173 and am about to move
# I am agent 4247 and am about to move
# I am agent 4256 and am about to move
# I am agent 4208 and am about to move
# I am agent 4322 and am about to move
# I am agent 4196 and am about to move
# I am agent 4323 and am about to move
# I am agent 4242 and am about to move
# I am agent 4161 and am about to move
# I am agent 4198 and am about to move
# I am agent 4331 and am about to move
# I am agent 4335 and am about to move
# I am agent 4299 and am about to move
# I am agent 4261 and am about to move
# I am agent 4179 and am about to move
# I am agent 4320 and am about to move
# I am agent 4282 and am about to move
# I am agent 4192 and am about to move
# I am agent 4193 and am about to move
# I am agent 4305 and am about to move
# I am agent 4283 and am about to move
# I am agent 4301 and am about to move
# I am agent 4272 and am about to move
# I am agent 4232 and am about to move
# I am agent 4292 and am about to move
# I am agent 4157 and am about to move
# I am agent 4303 and am about to move
# I am agent 4163 and am about to move
# I am agent 4251 and am about to move
# I am agent 4324 and am about to move
# I am agent 4278 and am about to move
# I am agent 4310 and am about to move
# I am agent 4332 and am about to move
# I am agent 4302 and am about to move
# I am agent 4231 and am about to move
# I am agent 4246 and am about to move
# I am agent 4200 and am about to move
# I am agent 4141 and am about to move
# I am agent 4214 and am about to move
# I am agent 4186 and am about to move
# I am agent 4183 and am about to move
# I am agent 4265 and am about to move
# I am agent 4143 and am about to move
# I am agent 4145 and am about to move
# I am agent 4201 and am about to move
# I am agent 4168 and am about to move
# I am agent 4195 and am about to move
# I am agent 4148 and am about to move
# I am agent 4263 and am about to move
# I am agent 4185 and am about to move
# I am agent 4152 and am about to move
# I am agent 4206 and am about to move
# I am agent 4220 and am about to move
# I am agent 4147 and am about to move
# I am agent 4211 and am about to move
# I am agent 4238 and am about to move
# I am agent 4215 and am about to move
# I am agent 4165 and am about to move
# I am agent 4334 and am about to move
# I am agent 4249 and am about to move
# I am agent 4194 and am about to move
# I am agent 4313 and am about to move
# I am agent 4197 and am about to move
# I am agent 4170 and am about to move
# I am agent 4209 and am about to move
# I am agent 4330 and am about to move
# I am agent 4280 and am about to move
# I am agent 4264 and am about to move
# I am agent 4295 and am about to move
# I am agent 4227 and am about to move
# I am agent 4255 and am about to move
# I am agent 4167 and am about to move
# I am agent 4199 and am about to move
# I am agent 4189 and am about to move
# I am agent 4271 and am about to move
# I am agent 4139 and am about to move
# I am agent 4218 and am about to move
# I am agent 4304 and am about to move
# I am agent 4176 and am about to move
# I am agent 4336 and am about to move
# I am agent 4319 and am about to move
# I am agent 4169 and am about to move
# I am agent 4221 and am about to move
# I am agent 4177 and am about to move
# I am agent 4153 and am about to move
# I am agent 4159 and am about to move
# I am agent 4156 and am about to move
# I am agent 4248 and am about to move
# I am agent 4224 and am about to move
# I am agent 4237 and am about to move
# I am agent 4182 and am about to move
# I am agent 4262 and am about to move
# I am agent 4180 and am about to move
# I am agent 4213 and am about to move
# I am agent 4257 and am about to move
# I am agent 4279 and am about to move
# I am agent 4223 and am about to move
# I am agent 4172 and am about to move
# I am agent 4234 and am about to move
# I am agent 4235 and am about to move
# I am agent 4154 and am about to move
# I am agent 4243 and am about to move
# I am agent 4228 and am about to move
# I am agent 4290 and am about to move
# I am agent 4329 and am about to move
# I am agent 4325 and am about to move
# I am agent 4181 and am about to move
# I am agent 4203 and am about to move
# I am agent 4155 and am about to move
# I am agent 4250 and am about to move
# I am agent 4158 and am about to move
# I am agent 4204 and am about to move
# I am agent 4312 and am about to move
# I am agent 4307 and am about to move
# I am agent 4166 and am about to move
# I am agent 4149 and am about to move
# I am agent 4162 and am about to move
# I am agent 4321 and am about to move
# I am agent 4230 and am about to move
# I am agent 4315 and am about to move
# I am agent 4311 and am about to move
# I am agent 4274 and am about to move
# I am agent 4275 and am about to move
# I am agent 4252 and am about to move
# I am agent 4207 and am about to move
# I am agent 4286 and am about to move
# I am agent 4337 and am about to move
# I am agent 4240 and am about to move
# I am agent 4241 and am about to move
# I am agent 4222 and am about to move
# I am agent 4293 and am about to move
# I am agent 4314 and am about to move
# I am agent 4277 and am about to move
# I am agent 4174 and am about to move
# I am agent 4281 and am about to move
# I am agent 4268 and am about to move
# I am agent 4326 and am about to move
# I am agent 4171 and am about to move
# I am agent 4287 and am about to move
# I am agent 4178 and am about to move
# I am agent 4205 and am about to move
# I am agent 4276 and am about to move
# I am agent 4308 and am about to move
# I am agent 4300 and am about to move
# I am agent 4217 and am about to move
# I am agent 4269 and am about to move
# I am agent 4294 and am about to move
# I am agent 4184 and am about to move
# I am agent 4202 and am about to move
# I am agent 4225 and am about to move
# I am agent 4219 and am about to move
# I am agent 4317 and am about to move
# I am agent 4327 and am about to move
# I am agent 4288 and am about to move
# I am agent 4140 and am about to move
# I am agent 4236 and am about to move
# I am agent 4253 and am about to move
# I am agent 4187 and am about to move
# I am agent 4309 and am about to move
# I am agent 4216 and am about to move
# I am agent 4191 and am about to move
# I am agent 4229 and am about to move
# I am agent 4298 and am about to move
# I am agent 4239 and am about to move
# I am agent 4150 and am about to move
# I am agent 4260 and am about to move
# I am agent 4270 and am about to move
# I am agent 4233 and am about to move
# I am agent 4258 and am about to move
# I am agent 4254 and am about to move
# I am agent 4316 and am about to move
# I am agent 4291 and am about to move
# I am agent 4142 and am about to move
# I am agent 4306 and am about to move
# I am agent 4296 and am about to move
# I am agent 4333 and am about to move
# I am agent 4212 and am about to move
# I am agent 4297 and am about to move
# I am agent 4146 and am about to move
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 0 is being placed with
# place_agent() despite already having the position (0, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 2 is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 3 is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 4 is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 5 is being placed with
# place_agent() despite already having the position (0, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 6 is being placed with
# place_agent() despite already having the position (0, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 7 is being placed with
# place_agent() despite already having the position (0, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 8 is being placed with
# place_agent() despite already having the position (0, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 9 is being placed with
# place_agent() despite already having the position (0, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 10 is being placed with
# place_agent() despite already having the position (0, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 11 is being placed with
# place_agent() despite already having the position (0, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 12 is being placed with
# place_agent() despite already having the position (0, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 13 is being placed with
# place_agent() despite already having the position (0, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 14 is being placed with
# place_agent() despite already having the position (0, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 15 is being placed with
# place_agent() despite already having the position (0, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 16 is being placed with
# place_agent() despite already having the position (0, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 17 is being placed with
# place_agent() despite already having the position (0, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 18 is being placed with
# place_agent() despite already having the position (0, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 19 is being placed with
# place_agent() despite already having the position (0, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 20 is being placed with
# place_agent() despite already having the position (0, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 21 is being placed with
# place_agent() despite already having the position (0, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 22 is being placed with
# place_agent() despite already having the position (0, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 23 is being placed with
# place_agent() despite already having the position (0, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 24 is being placed with
# place_agent() despite already having the position (0, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 25 is being placed with
# place_agent() despite already having the position (0, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 26 is being placed with
# place_agent() despite already having the position (0, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 27 is being placed with
# place_agent() despite already having the position (0, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 28 is being placed with
# place_agent() despite already having the position (0, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 29 is being placed with
# place_agent() despite already having the position (0, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 30 is being placed with
# place_agent() despite already having the position (0, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 31 is being placed with
# place_agent() despite already having the position (0, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 32 is being placed with
# place_agent() despite already having the position (0, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 33 is being placed with
# place_agent() despite already having the position (0, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 34 is being placed with
# place_agent() despite already having the position (0, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 35 is being placed with
# place_agent() despite already having the position (0, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 36 is being placed with
# place_agent() despite already having the position (0, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 37 is being placed with
# place_agent() despite already having the position (0, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 38 is being placed with
# place_agent() despite already having the position (0, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 39 is being placed with
# place_agent() despite already having the position (0, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 40 is being placed with
# place_agent() despite already having the position (0, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 41 is being placed with
# place_agent() despite already having the position (0, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 42 is being placed with
# place_agent() despite already having the position (0, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 43 is being placed with
# place_agent() despite already having the position (0, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 44 is being placed with
# place_agent() despite already having the position (0, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 45 is being placed with
# place_agent() despite already having the position (0, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 46 is being placed with
# place_agent() despite already having the position (0, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 47 is being placed with
# place_agent() despite already having the position (0, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 48 is being placed with
# place_agent() despite already having the position (0, 34). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 49 is being placed with
# place_agent() despite already having the position (0, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 50 is being placed with
# place_agent() despite already having the position (0, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 51 is being placed with
# place_agent() despite already having the position (0, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 52 is being placed with
# place_agent() despite already having the position (0, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 53 is being placed with
# place_agent() despite already having the position (0, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 54 is being placed with
# place_agent() despite already having the position (0, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 55 is being placed with
# place_agent() despite already having the position (0, 41). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 56 is being placed with
# place_agent() despite already having the position (0, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 57 is being placed with
# place_agent() despite already having the position (0, 43). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 58 is being placed with
# place_agent() despite already having the position (0, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 59 is being placed with
# place_agent() despite already having the position (0, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 60 is being placed with
# place_agent() despite already having the position (0, 46). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 61 is being placed with
# place_agent() despite already having the position (0, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 62 is being placed with
# place_agent() despite already having the position (0, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 63 is being placed with
# place_agent() despite already having the position (0, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 64 is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 65 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 66 is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 67 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 68 is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 69 is being placed with
# place_agent() despite already having the position (1, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 70 is being placed with
# place_agent() despite already having the position (1, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 71 is being placed with
# place_agent() despite already having the position (1, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 72 is being placed with
# place_agent() despite already having the position (1, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 73 is being placed with
# place_agent() despite already having the position (1, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 74 is being placed with
# place_agent() despite already having the position (1, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 75 is being placed with
# place_agent() despite already having the position (1, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 76 is being placed with
# place_agent() despite already having the position (1, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 77 is being placed with
# place_agent() despite already having the position (1, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 78 is being placed with
# place_agent() despite already having the position (1, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 79 is being placed with
# place_agent() despite already having the position (1, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 80 is being placed with
# place_agent() despite already having the position (1, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 81 is being placed with
# place_agent() despite already having the position (1, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 82 is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 83 is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 84 is being placed with
# place_agent() despite already having the position (1, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 85 is being placed with
# place_agent() despite already having the position (1, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 86 is being placed with
# place_agent() despite already having the position (1, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 87 is being placed with
# place_agent() despite already having the position (1, 20). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 88 is being placed with
# place_agent() despite already having the position (1, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 89 is being placed with
# place_agent() despite already having the position (1, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 90 is being placed with
# place_agent() despite already having the position (1, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 91 is being placed with
# place_agent() despite already having the position (1, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 92 is being placed with
# place_agent() despite already having the position (1, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 93 is being placed with
# place_agent() despite already having the position (1, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 94 is being placed with
# place_agent() despite already having the position (1, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 95 is being placed with
# place_agent() despite already having the position (1, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 96 is being placed with
# place_agent() despite already having the position (1, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 97 is being placed with
# place_agent() despite already having the position (1, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 98 is being placed with
# place_agent() despite already having the position (1, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 99 is being placed with
# place_agent() despite already having the position (1, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 100 is being placed with
# place_agent() despite already having the position (1, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 101 is being placed with
# place_agent() despite already having the position (1, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 102 is being placed with
# place_agent() despite already having the position (1, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 103 is being placed with
# place_agent() despite already having the position (1, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 104 is being placed with
# place_agent() despite already having the position (1, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 105 is being placed with
# place_agent() despite already having the position (1, 29). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 106 is being placed with
# place_agent() despite already having the position (1, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 107 is being placed with
# place_agent() despite already having the position (1, 30). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 108 is being placed with
# place_agent() despite already having the position (1, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:48: UserWarning: Agent 109 is being placed with
# place_agent() despite already having the position (1, 31). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(spice, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 110 is being placed with
# place_agent() despite already having the position (1, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 111 is being placed with
# place_agent() despite already having the position (1, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 112 is being placed with
# place_agent() despite already having the position (1, 34). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 113 is being placed with
# place_agent() despite already having the position (1, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 114 is being placed with
# place_agent() despite already having the position (1, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 115 is being placed with
# place_agent() despite already having the position (1, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 116 is being placed with
# place_agent() despite already having the position (1, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 117 is being placed with
# place_agent() despite already having the position (1, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 118 is being placed with
# place_agent() despite already having the position (1, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 119 is being placed with
# place_agent() despite already having the position (1, 41). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 120 is being placed with
# place_agent() despite already having the position (1, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 121 is being placed with
# place_agent() despite already having the position (1, 43). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 122 is being placed with
# place_agent() despite already having the position (1, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 123 is being placed with
# place_agent() despite already having the position (1, 45). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 124 is being placed with
# place_agent() despite already having the position (1, 46). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 125 is being placed with
# place_agent() despite already having the position (1, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 126 is being placed with
# place_agent() despite already having the position (1, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(sugar, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:41: UserWarning: Agent 127 is being placed with
# place_agent() despite already having the position (1, 49). In most
# ...
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4292 is being placed with
# place_agent() despite already having the position (8, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4293 is being placed with
# place_agent() despite already having the position (23, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4294 is being placed with
# place_agent() despite already having the position (42, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4295 is being placed with
# place_agent() despite already having the position (40, 36). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4296 is being placed with
# place_agent() despite already having the position (26, 26). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4297 is being placed with
# place_agent() despite already having the position (33, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4298 is being placed with
# place_agent() despite already having the position (18, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4299 is being placed with
# place_agent() despite already having the position (0, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4300 is being placed with
# place_agent() despite already having the position (28, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4301 is being placed with
# place_agent() despite already having the position (43, 47). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4302 is being placed with
# place_agent() despite already having the position (41, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4303 is being placed with
# place_agent() despite already having the position (1, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4304 is being placed with
# place_agent() despite already having the position (36, 23). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4305 is being placed with
# place_agent() despite already having the position (2, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4306 is being placed with
# place_agent() despite already having the position (16, 22). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4307 is being placed with
# place_agent() despite already having the position (34, 25). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4308 is being placed with
# place_agent() despite already having the position (47, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4309 is being placed with
# place_agent() despite already having the position (45, 33). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4310 is being placed with
# place_agent() despite already having the position (13, 27). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4311 is being placed with
# place_agent() despite already having the position (17, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4312 is being placed with
# place_agent() despite already having the position (18, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4313 is being placed with
# place_agent() despite already having the position (7, 28). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4314 is being placed with
# place_agent() despite already having the position (5, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4315 is being placed with
# place_agent() despite already having the position (20, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4316 is being placed with
# place_agent() despite already having the position (25, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4317 is being placed with
# place_agent() despite already having the position (44, 49). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4318 is being placed with
# place_agent() despite already having the position (39, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4319 is being placed with
# place_agent() despite already having the position (22, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4320 is being placed with
# place_agent() despite already having the position (35, 35). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4321 is being placed with
# place_agent() despite already having the position (3, 39). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4322 is being placed with
# place_agent() despite already having the position (17, 38). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4323 is being placed with
# place_agent() despite already having the position (23, 40). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4324 is being placed with
# place_agent() despite already having the position (35, 24). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4325 is being placed with
# place_agent() despite already having the position (26, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4326 is being placed with
# place_agent() despite already having the position (48, 21). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4327 is being placed with
# place_agent() despite already having the position (0, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4328 is being placed with
# place_agent() despite already having the position (14, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4329 is being placed with
# place_agent() despite already having the position (0, 48). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4330 is being placed with
# place_agent() despite already having the position (35, 44). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4331 is being placed with
# place_agent() despite already having the position (42, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4332 is being placed with
# place_agent() despite already having the position (0, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4333 is being placed with
# place_agent() despite already having the position (26, 42). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4334 is being placed with
# place_agent() despite already having the position (19, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4335 is being placed with
# place_agent() despite already having the position (49, 32). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4336 is being placed with
# place_agent() despite already having the position (47, 37). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:74: UserWarning: Agent 4337 is being placed with
# place_agent() despite already having the position (7, 34). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(trader, (x, y))
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:84: DeprecationWarning: Because of the shift to using AgentSet, in the future this attribute will return a dict withtype as key as AgentSet as value. Future behavior is available via RandomActivationByType._agents_by_type
#   for sugar in self.schedule.agents_by_type[Sugar].values():
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:88: DeprecationWarning: Because of the shift to using AgentSet, in the future this attribute will return a dict withtype as key as AgentSet as value. Future behavior is available via RandomActivationByType._agents_by_type
#   for spice in self.schedule.agents_by_type[Spice].values():
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13356\2607841188.py:92: DeprecationWarning: Because of the shift to using AgentSet, in the future this attribute will return a dict withtype as key as AgentSet as value. Future behavior is available via RandomActivationByType._agents_by_type
#   trader_shuffle = list(self.schedule.agents_by_type[Trader].values())
